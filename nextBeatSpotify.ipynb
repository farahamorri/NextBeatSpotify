# %% [markdown]
# ### 1. Configuration et chargement

# %%
# !pip install scikit-learn    
# !pip  install tensorflow      
# !pip install keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub
import os

# Configuration de l'affichage pour voir toutes les colonnes
pd.set_option('display.max_columns', None)

# 1. Chargement du dataset
# 1. Téléchargement du dataset (dernière version)
path = kagglehub.dataset_download("joebeachcapital/30000-spotify-songs")
print("✅ Dataset téléchargé à l'adresse :", path)

# 2. Lister les fichiers pour trouver le CSV
files = os.listdir(path)
csv_file = [f for f in files if f.endswith('.csv')][0]
full_path = os.path.join(path, csv_file)

# 3. Chargement dans un DataFrame Pandas
df = pd.read_csv(full_path)
# 2. Premier aperçu des données
print("\n--- Aperçu des 5 premières lignes ---")
display(df.head())

# 3. Structure du dataset (Nombre de lignes/colonnes et types)
print("\n--- Informations sur le dataset ---")
df.info()

# 4. Vérification des statistiques de base
print("\n--- Statistiques descriptives ---")
display(df.describe())
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.4.1)
# ✅ Dataset téléchargé à l'adresse : /Users/farahamorri/.cache/kagglehub/datasets/joebeachcapital/30000-spotify-songs/versions/2
#
# --- Aperçu des 5 premières lignes ---
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre playlist_subgenre  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916    6    -2.634     1       0.0583        0.1020
# 1         0.726   0.815   11    -4.969     1       0.0373        0.0724
# 2         0.675   0.931    1    -3.432     0       0.0742        0.0794
# 3         0.718   0.930    7    -3.778     1       0.1020        0.0287
# 4         0.650   0.833    1    -4.672     1       0.0359        0.0803
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000000    0.0653    0.518  122.036       194754
# 1          0.004210    0.3570    0.693   99.972       162600
# 2          0.000023    0.1100    0.613  124.008       176616
# 3          0.000009    0.2040    0.277  121.956       169093
# 4          0.000000    0.0833    0.725  123.976       189052
# --- Informations sur le dataset ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB
#
# --- Statistiques descriptives ---
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# 25%       -8.171000      0.000000      0.041000      0.015100
# 50%       -6.166000      1.000000      0.062500      0.080400
# 75%       -4.645000      1.000000      0.132000      0.255000
# max        1.275000      1.000000      0.918000      0.994000
#
#        instrumentalness      liveness       valence         tempo  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean           0.084747      0.190176      0.510561    120.881132
# std            0.224230      0.154317      0.233146     26.903624
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.092700      0.331000     99.960000
# 50%            0.000016      0.127000      0.512000    121.984000
# 75%            0.004830      0.248000      0.693000    133.918000
# max            0.994000      0.996000      0.991000    239.440000
#
#          duration_ms
# count   32833.000000
# mean   225799.811622
# std     59834.006182
# min      4000.000000
# 25%    187819.000000
# 50%    216000.000000
# 75%    253585.000000
# max    517810.000000

# %% [markdown]
# ### 2. Nettoyage et exploration

# %%
# 1. Suppression des doublons
# Dans les datasets Spotify, une chanson peut apparaître plusieurs fois si elle est dans plusieurs albums.
print(f"Nombre de lignes avant : {len(df)}")
df = df.drop_duplicates(subset=['track_name', 'track_artist'])
print(f"Nombre de lignes après suppression des doublons : {len(df)}")

# 2. Nettoyage de la colonne 'track_artist' (pour enlever les crochets et guillemets)
# La colonne est souvent sous forme de chaîne "[ 'Artiste' ]"
df['track_artist'] = df['track_artist'].str.replace("[", "").str.replace("]", "").str.replace("'", "")

# 3. Sélection des caractéristiques audio (Features)
# On ne garde que les colonnes numériques qui décrivent le "son"
audio_features = [
    'danceability', 'energy', 'key', 'loudness', 'mode', 
    'speechiness', 'acousticness', 'instrumentalness', 
    'liveness', 'valence', 'tempo'
]

# On crée un nouveau DataFrame avec uniquement ces colonnes pour l'analyse
df_features = df[audio_features]

# 4. Vérification des valeurs manquantes
print("\nValeurs manquantes par colonne :")
print(df_features.isnull().sum())

# 5. Visualisation : Matrice de Corrélation
# Cela permet de voir si certaines caractéristiques sont liées (ex: Energy et Loudness)
plt.figure(figsize=(12, 8))
sns.heatmap(df_features.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Corrélation entre les caractéristiques audio")
plt.show()

# 6. Distribution d'une feature (Exemple : Danceability)
plt.figure(figsize=(10, 4))
sns.histplot(df['danceability'], kde=True, color='green')
plt.title("Distribution de la Danceability dans le dataset")
plt.show()
# Out:
# Nombre de lignes avant : 32833
# Nombre de lignes après suppression des doublons : 26230
#
# Valeurs manquantes par colonne :
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# dtype: int64

# %% [markdown]
# ### 3. Prétraitement: la Normalisation

# %%
from sklearn.preprocessing import MinMaxScaler

# 1. Initialisation du Scaler
# On utilise MinMaxScaler pour ramener toutes les valeurs entre 0 et 1.
# Cela préserve la distribution originale tout en égalisant l'importance de chaque feature.
scaler = MinMaxScaler()

# 2. Application de la normalisation
# Nous appliquons le scaler sur notre DataFrame 'df_features' créé à l'étape précédente.
scaled_features = scaler.fit_transform(df_features)

# 3. Création d'un DataFrame avec les données normalisées
# On conserve les noms de colonnes et l'index original pour pouvoir retrouver les chansons plus tard.
df_scaled = pd.DataFrame(scaled_features, columns=audio_features, index=df.index)

# 4. Vérification du résultat
print("--- Aperçu des données normalisées ---")
display(df_scaled.head())

# Vérification que toutes les valeurs sont bien entre 0 et 1
print("\nStatistiques après normalisation (Min/Max) :")
print(f"Minimum global : {df_scaled.min().min()}")
print(f"Maximum global : {df_scaled.max().max()}")
# Out:
# --- Aperçu des données normalisées ---
#    danceability    energy       key  loudness  mode  speechiness  \
# 0      0.760936  0.915985  0.545455  0.918090   1.0     0.063508
# 1      0.738555  0.814968  1.000000  0.869162   1.0     0.040632
# 2      0.686673  0.930988  0.090909  0.901368   0.0     0.080828
# 3      0.730417  0.929988  0.636364  0.894118   1.0     0.111111
# 4      0.661241  0.832971  0.090909  0.875385   1.0     0.039107
#
#    acousticness  instrumentalness  liveness   valence     tempo
# 0      0.102616          0.000000  0.065562  0.522704  0.509673
# 1      0.072837          0.004235  0.358434  0.699294  0.417524
# 2      0.079879          0.000023  0.110442  0.618567  0.517908
# 3      0.028873          0.000009  0.204819  0.279516  0.509338
# 4      0.080785          0.000000  0.083635  0.731584  0.517775
# Statistiques après normalisation (Min/Max) :
# Minimum global : 0.0
# Maximum global : 1.0

# %% [markdown]
# ### 4. Construction de l'Autoencoder

# %%
import tensorflow as tf
from keras import layers, models

# 1. Définition de la dimension d'entrée (le nombre de features audio)
input_dim = df_scaled.shape[1] 
latent_dim = 4  # On compresse les 11 features en 4 "super-features"

# 2. L'ENCODEUR
input_layer = layers.Input(shape=(input_dim,))
encoded = layers.Dense(8, activation='relu')(input_layer)
bottleneck = layers.Dense(latent_dim, activation='relu')(encoded)

# 3. LE DÉCODEUR
decoded = layers.Dense(8, activation='relu')(bottleneck)
output_layer = layers.Dense(input_dim, activation='sigmoid')(decoded)

# 4. LE MODÈLE COMPLET (Autoencoder)
autoencoder = models.Model(inputs=input_layer, outputs=output_layer)

# 5. L'ENCODEUR SEUL (Pour la recommandation)
encoder = models.Model(inputs=input_layer, outputs=bottleneck)

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 11)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 8)              │            96 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 11)             │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 271 (1.06 KB)
#  Trainable params: 271 (1.06 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 5. Entrainement du modèle

# %%
# Entraînement
history = autoencoder.fit(
    df_scaled, df_scaled,
    epochs=50,
    batch_size=32,
    shuffle=True,
    validation_split=0.1,
    verbose=1
)

# Visualisation de la perte
plt.plot(history.history['loss'], label='Perte Entraînement')
plt.plot(history.history['val_loss'], label='Perte Validation')
plt.legend()
plt.title("Évolution de l'apprentissage")
plt.show()
# Out:
# Epoch 1/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 1s 421us/step - loss: 0.0834 - val_loss: 0.0353
# Epoch 2/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 0.0255 - val_loss: 0.0275
# Epoch 3/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 0.0196 - val_loss: 0.0238
# Epoch 4/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 0.0168 - val_loss: 0.0214
# Epoch 5/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - loss: 0.0158 - val_loss: 0.0203
# Epoch 6/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - loss: 0.0153 - val_loss: 0.0193
# Epoch 7/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 0.0145 - val_loss: 0.0176
# Epoch 8/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step - loss: 0.0138 - val_loss: 0.0166
# Epoch 9/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 0.0135 - val_loss: 0.0158
# Epoch 10/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 0.0131 - val_loss: 0.0147
# Epoch 11/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 0.0127 - val_loss: 0.0150
# Epoch 12/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 0.0127 - val_loss: 0.0154
# Epoch 13/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 0.0124 - val_loss: 0.0152
# Epoch 14/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.0122 - val_loss: 0.0156
# Epoch 15/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 0.0120 - val_loss: 0.0152
# Epoch 16/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 0.0119 - val_loss: 0.0151
# Epoch 17/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 0.0120 - val_loss: 0.0149
# Epoch 18/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 0.0117 - val_loss: 0.0150
# Epoch 19/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.0116 - val_loss: 0.0145
# Epoch 20/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 0.0117 - val_loss: 0.0146
# Epoch 21/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 0.0115 - val_loss: 0.0146
# Epoch 22/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.0116 - val_loss: 0.0144
# Epoch 23/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 0.0117 - val_loss: 0.0147
# Epoch 24/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 0.0115 - val_loss: 0.0144
# Epoch 25/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.0113 - val_loss: 0.0141
# Epoch 26/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 0.0115 - val_loss: 0.0141
# Epoch 27/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 0.0113 - val_loss: 0.0141
# Epoch 28/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 0.0114 - val_loss: 0.0137
# Epoch 29/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 0.0112 - val_loss: 0.0140
# Epoch 30/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.0113 - val_loss: 0.0139
# Epoch 31/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 0.0113 - val_loss: 0.0133
# Epoch 32/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.0112 - val_loss: 0.0137
# Epoch 33/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 0.0113 - val_loss: 0.0134
# Epoch 34/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 0.0110 - val_loss: 0.0136
# Epoch 35/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 0.0111 - val_loss: 0.0136
# Epoch 36/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0114 - val_loss: 0.0138
# Epoch 37/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.0111 - val_loss: 0.0136
# Epoch 38/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 0.0113 - val_loss: 0.0132
# Epoch 39/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 0.0113 - val_loss: 0.0136
# Epoch 40/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - loss: 0.0110 - val_loss: 0.0142
# Epoch 41/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0110 - val_loss: 0.0134
# Epoch 42/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.0111 - val_loss: 0.0134
# Epoch 43/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.0112 - val_loss: 0.0135
# Epoch 44/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.0112 - val_loss: 0.0131
# Epoch 45/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 0.0111 - val_loss: 0.0133
# Epoch 46/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 0.0111 - val_loss: 0.0133
# Epoch 47/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 0.0111 - val_loss: 0.0133
# Epoch 48/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 0.0110 - val_loss: 0.0130
# Epoch 49/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.0111 - val_loss: 0.0130
# Epoch 50/50
# 738/738 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 0.0111 - val_loss: 0.0140

# %% [markdown]
# ### 6. Génération des recommandations

# %%
from sklearn.metrics.pairwise import cosine_similarity

# 1. On compresse toutes les chansons dans l'espace latent
latent_vectors = encoder.predict(df_scaled)

def recommend_with_autoencoder(song_name, df, latent_vectors, n_recs=5):
    if song_name not in df['track_name'].values:
        return "Chanson non trouvée."

    # Index de la chanson
    idx = df[df['track_name'] == song_name].index[0]
    
    # Vecteur latent de la chanson cible
    target_vector = latent_vectors[idx].reshape(1, -1)
    
    # Similarité dans l'espace latent
    similarity = cosine_similarity(target_vector, latent_vectors)
    
    # Top indices
    similar_indices = similarity[0].argsort()[::-1][1:n_recs+1]
    
    return df.iloc[similar_indices][['track_name', 'track_artist', 'track_album_release_date']]

# TEST
print("Recommandations via Autoencoder For the Track: " + str(df['track_name'].iloc[34]))
display(recommend_with_autoencoder(df['track_name'].iloc[34], df, latent_vectors))
# Out:
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step
# Recommandations via Autoencoder For the Track: Quite Miss Home - Steve Void Remix
#                   track_name        track_artist track_album_release_date
# 539            Something New  Axwell /\ Ingrosso               2015-01-20
# 7579                      23   Mike WiLL Made-It               2013-01-01
# 29333      Middle - 4B Remix            DJ Snake               2015-10-16
# 7112     Throw Your Hands Up               8Ball               1999-05-18
# 8635   Many Men (Wish Death)             50 Cent               2003-02-06

# %% [markdown]
# ---

# %% [markdown]
# ### 4 bis. Construction de l'Autoencoder: Variational Autoencoder (VAE)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

class Sampling(layers.Layer):
    """Utilise (z_mean, z_log_var) pour échantillonner z (le vecteur latent)."""
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_dim = 4 # Taille de ton espace latent (le "résumé" de la musique)
input_dim = df_scaled.shape[1]

# --- ENCODEUR ---
encoder_inputs = keras.Input(shape=(input_dim,))
x = layers.Dense(16, activation="relu")(encoder_inputs)
x = layers.Dense(8, activation="relu")(x)

z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

# --- DÉCODEUR ---
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(8, activation="relu")(latent_inputs)
x = layers.Dense(16, activation="relu")(x)
decoder_outputs = layers.Dense(input_dim, activation="sigmoid")(x)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")

# %% [markdown]
# ### 5 bis. Entrainement du modèle

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            # Perte de reconstruction
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(keras.losses.mse(data, reconstruction), axis=-1)
            )
            
            # Perte KL (Régularisation)
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=-1))
            
            total_loss = reconstruction_loss + kl_loss
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {"loss": total_loss, "reconstruction_loss": reconstruction_loss, "kl_loss": kl_loss}

# Entraînement
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
history_vae = vae.fit(df_scaled, epochs=50, batch_size=32)


# Visualisation de la perte
plt.figure(figsize=(14, 5))

# Sous-graphique 1 : Perte Totale
plt.subplot(1, 2, 1)
plt.plot(history_vae.history['loss'], label='Total Loss', color='purple', lw=2)
plt.title("Évolution de la Perte Totale (VAE)")
plt.xlabel("Époques")
plt.ylabel("Loss")
plt.legend()
plt.grid(alpha=0.3)

# Sous-graphique 2 : Décomposition Reconstruction vs KL
plt.subplot(1, 2, 2)
plt.plot(history_vae.history['reconstruction_loss'], label='Reconstruction Loss', color='blue')
plt.plot(history_vae.history['kl_loss'], label='KL Divergence Loss', color='orange')
plt.title("Reconstruction vs Régularisation KL")
plt.xlabel("Époques")
plt.ylabel("Loss")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 1s 375us/step - kl_loss: 0.0121 - loss: 2.1440 - reconstruction_loss: 2.1319
# Epoch 2/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - kl_loss: 6.5675e-04 - loss: 1.8404 - reconstruction_loss: 1.8398
# Epoch 3/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - kl_loss: 4.0728e-04 - loss: 1.8350 - reconstruction_loss: 1.8346
# Epoch 4/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - kl_loss: 2.6608e-04 - loss: 1.8321 - reconstruction_loss: 1.8318
# Epoch 5/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - kl_loss: 1.1463e-04 - loss: 1.8323 - reconstruction_loss: 1.8321
# Epoch 6/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - kl_loss: 1.3438e-04 - loss: 1.8309 - reconstruction_loss: 1.8308
# Epoch 7/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - kl_loss: 0.0031 - loss: 1.8290 - reconstruction_loss: 1.8259
# Epoch 8/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - kl_loss: 0.0230 - loss: 1.8242 - reconstruction_loss: 1.8012
# Epoch 9/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - kl_loss: 0.1040 - loss: 1.8093 - reconstruction_loss: 1.7053
# Epoch 10/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - kl_loss: 0.1669 - loss: 1.7973 - reconstruction_loss: 1.6304
# Epoch 11/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - kl_loss: 0.2420 - loss: 1.7801 - reconstruction_loss: 1.5382
# Epoch 12/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - kl_loss: 0.2828 - loss: 1.7775 - reconstruction_loss: 1.4946
# Epoch 13/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - kl_loss: 0.2788 - loss: 1.7699 - reconstruction_loss: 1.4911
# Epoch 14/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - kl_loss: 0.2847 - loss: 1.7780 - reconstruction_loss: 1.4933
# Epoch 15/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - kl_loss: 0.2855 - loss: 1.7785 - reconstruction_loss: 1.4929
# Epoch 16/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - kl_loss: 0.2871 - loss: 1.7684 - reconstruction_loss: 1.4813
# Epoch 17/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - kl_loss: 0.2884 - loss: 1.7727 - reconstruction_loss: 1.4843
# Epoch 18/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - kl_loss: 0.2898 - loss: 1.7777 - reconstruction_loss: 1.4879
# Epoch 19/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - kl_loss: 0.2847 - loss: 1.7711 - reconstruction_loss: 1.4864
# Epoch 20/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - kl_loss: 0.2833 - loss: 1.7742 - reconstruction_loss: 1.4909
# Epoch 21/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - kl_loss: 0.2815 - loss: 1.7762 - reconstruction_loss: 1.4947
# Epoch 22/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 358us/step - kl_loss: 0.2800 - loss: 1.7651 - reconstruction_loss: 1.4851
# Epoch 23/50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step
50
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - kl_loss: 0.2863 - loss: 1.7745 - reconstruction_loss: 1.4882

# %%
# On réduit le learning rate (ex: 0.0005 au lieu de 0.001 par défaut)
optimizer = keras.optimizers.Adam(learning_rate=0.0005)
# Entraînement
vae = VAE(encoder, decoder)
vae.compile(optimizer=optimizer)

# 2. On augmente le batch_size pour lisser les gradients (ex: 64 ou 128)
history_vae = vae.fit(
    df_scaled, 
    epochs=100, # On peut doubler les époques comme le modèle apprend plus lentement
    batch_size=64, 
    shuffle=True,
    verbose=1
)


# Visualisation de la perte
plt.figure(figsize=(14, 5))

# Sous-graphique 1 : Perte Totale
plt.subplot(1, 2, 1)
plt.plot(history_vae.history['loss'], label='Total Loss', color='purple', lw=2)
plt.title("Évolution de la Perte Totale (VAE)")
plt.xlabel("Époques")
plt.ylabel("Loss")
plt.legend()
plt.grid(alpha=0.3)

# Sous-graphique 2 : Décomposition Reconstruction vs KL
plt.subplot(1, 2, 2)
plt.plot(history_vae.history['reconstruction_loss'], label='Reconstruction Loss', color='blue')
plt.plot(history_vae.history['kl_loss'], label='KL Divergence Loss', color='orange')
plt.title("Reconstruction vs Régularisation KL")
plt.xlabel("Époques")
plt.ylabel("Loss")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 1s 421us/step - kl_loss: 0.5398 - loss: 3.1190 - reconstruction_loss: 2.5792
# Epoch 2/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - kl_loss: 0.6121 - loss: 3.0793 - reconstruction_loss: 2.4672
# Epoch 3/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - kl_loss: 0.6259 - loss: 3.0737 - reconstruction_loss: 2.4478
# Epoch 4/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - kl_loss: 0.6325 - loss: 3.0726 - reconstruction_loss: 2.4401
# Epoch 5/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - kl_loss: 0.6397 - loss: 3.0737 - reconstruction_loss: 2.4340
# Epoch 6/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - kl_loss: 0.6352 - loss: 3.0698 - reconstruction_loss: 2.4346
# Epoch 7/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - kl_loss: 0.6454 - loss: 3.0725 - reconstruction_loss: 2.4271
# Epoch 8/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - kl_loss: 0.6430 - loss: 3.0679 - reconstruction_loss: 2.4249
# Epoch 9/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - kl_loss: 0.6501 - loss: 3.0699 - reconstruction_loss: 2.4198
# Epoch 10/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - kl_loss: 0.6446 - loss: 3.0609 - reconstruction_loss: 2.4163
# Epoch 11/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - kl_loss: 0.6457 - loss: 3.0686 - reconstruction_loss: 2.4229
# Epoch 12/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - kl_loss: 0.6515 - loss: 3.0700 - reconstruction_loss: 2.4185
# Epoch 13/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - kl_loss: 0.6564 - loss: 3.0777 - reconstruction_loss: 2.4213
# Epoch 14/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - kl_loss: 0.6548 - loss: 3.0627 - reconstruction_loss: 2.4079
# Epoch 15/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - kl_loss: 0.6592 - loss: 3.0705 - reconstruction_loss: 2.4112
# Epoch 16/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - kl_loss: 0.6639 - loss: 3.0715 - reconstruction_loss: 2.4076
# Epoch 17/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - kl_loss: 0.6657 - loss: 3.0663 - reconstruction_loss: 2.4006
# Epoch 18/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - kl_loss: 0.6630 - loss: 3.0665 - reconstruction_loss: 2.4035
# Epoch 19/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - kl_loss: 0.6616 - loss: 3.0631 - reconstruction_loss: 2.4015
# Epoch 20/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - kl_loss: 0.6691 - loss: 3.0718 - reconstruction_loss: 2.4026
# Epoch 21/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - kl_loss: 0.6673 - loss: 3.0659 - reconstruction_loss: 2.3987
# Epoch 22/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - kl_loss: 0.6741 - loss: 3.0674 - reconstruction_loss: 2.3933
# Epoch 23/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - kl_loss: 0.6668 - loss: 3.0587 - reconstruction_loss: 2.3919
# Epoch 24/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - kl_loss: 0.6679 - loss: 3.0555 - reconstruction_loss: 2.3876
# Epoch 25/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step
100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - kl_loss: 0.7733 - loss: 3.0381 - reconstruction_loss: 2.2648
# Epoch 89/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - kl_loss: 0.7768 - loss: 3.0451 - reconstruction_loss: 2.2682
# Epoch 90/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - kl_loss: 0.7699 - loss: 3.0352 - reconstruction_loss: 2.2652
# Epoch 91/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - kl_loss: 0.7607 - loss: 3.0393 - reconstruction_loss: 2.2786
# Epoch 92/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - kl_loss: 0.7616 - loss: 3.0347 - reconstruction_loss: 2.2731
# Epoch 93/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - kl_loss: 0.7804 - loss: 3.0469 - reconstruction_loss: 2.2665
# Epoch 94/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - kl_loss: 0.7697 - loss: 3.0417 - reconstruction_loss: 2.2720
# Epoch 95/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - kl_loss: 0.7682 - loss: 3.0390 - reconstruction_loss: 2.2708
# Epoch 96/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - kl_loss: 0.7756 - loss: 3.0449 - reconstruction_loss: 2.2693
# Epoch 97/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - kl_loss: 0.7648 - loss: 3.0332 - reconstruction_loss: 2.2684
# Epoch 98/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - kl_loss: 0.7743 - loss: 3.0364 - reconstruction_loss: 2.2621
# Epoch 99/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - kl_loss: 0.7732 - loss: 3.0333 - reconstruction_loss: 2.2601
# Epoch 100/100
# 410/410 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - kl_loss: 0.7727 - loss: 3.0324 - reconstruction_loss: 2.2598

# %% [markdown]
# #### 5 bis. Stabilisation de l'entrainement - Equilibrage de la perte (Beta-VAE)

# %%
class beta_VAE(keras.Model):
    def __init__(self, encoder, decoder, beta=1.0, **kwargs):
        super(beta_VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.beta = beta

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            # Perte de reconstruction
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(keras.losses.mse(data, reconstruction), axis=-1)
            )
            
            # Perte KL (Régularisation)
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=-1))
            
            # total_loss = reconstruction_loss + kl_loss
            total_loss = reconstruction_loss + (self.beta * kl_loss)
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        return {"loss": total_loss, "reconstruction_loss": reconstruction_loss, "kl_loss": kl_loss}

# %% [markdown]
# #### Grid-Search pour paramètre Beta

# %%
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split

# 0. Préparation des labels pour le score de silhouette
# On utilise souvent la colonne 'genre' ou une version encodée pour valider l'espace latent
labels = df['playlist_subgenre'] # Remplace 'genre' par le nom exact de ta colonne de catégorie

# 1. Préparer un set d'entraînement et de validation
x_train, x_val = train_test_split(df_scaled, test_size=0.2, random_state=42)

beta_values = [0.1, 0.5, 1.0, 2.0, 5.0]
results = {}

for b in beta_values:
    print(f"\n🚀 Test avec beta = {b}")
    
    # Réinitialisation/Re-création du modèle pour chaque beta
    vae_test = beta_VAE(encoder, decoder, beta=b)
    vae_test.compile(optimizer=keras.optimizers.Adam(learning_rate=5e-5))
    
    history = vae_test.fit(
        x_train, 
        epochs=50, 
        batch_size=128, 
        verbose=0 
    )
    
    # 2. Calcul du score de silhouette
    # On projette les données de validation dans l'espace latent (z_mean)
    z_mean_val, _, _ = vae_test.encoder.predict(x_val)
    
    # On récupère les labels correspondants aux données de validation
    labels_val = labels.loc[x_val.index]
    
    # Calcul du score (mesure la séparation des genres dans l'espace latent)
    sil_score = silhouette_score(z_mean_val, labels_val)
    print(f"✨ Score de Silhouette : {sil_score:.4f}")

    # 3. Stockage des résultats complets
    results[b] = {
        'recon_loss': history.history['reconstruction_loss'][-1],
        'kl_loss': history.history['kl_loss'][-1],
        'silhouette': sil_score
    }
# Out:
# 🚀 Test avec beta = 0.1
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step
# ✨ Score de Silhouette : -0.1495
#
# 🚀 Test avec beta = 0.5
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 253us/step
# ✨ Score de Silhouette : -0.1389
#
# 🚀 Test avec beta = 1.0
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step
# ✨ Score de Silhouette : -0.1426
#
# 🚀 Test avec beta = 2.0
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 255us/step
# ✨ Score de Silhouette : -0.1539
#
# 🚀 Test avec beta = 5.0
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 253us/step
# ✨ Score de Silhouette : -0.1924

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Préparation des données à partir du dictionnaire 'results'
betas = sorted(results.keys())
recon_losses = [results[b]['recon_loss'] for b in betas]
kl_losses = [results[b]['kl_loss'] for b in betas]
silhouette_scores = [results[b]['silhouette'] for b in betas]

# --- PLOT 1 : ÉVOLUTION DES LOSS (Double axe Y) ---
fig, ax1 = plt.subplots(figsize=(10, 6))

color_recon = 'tab:blue'
ax1.set_xlabel('Valeur de Beta ($\\beta$)')
ax1.set_ylabel('Reconstruction Loss (MSE)', color=color_recon, fontsize=12)
ax1.plot(betas, recon_losses, marker='o', color=color_recon, linewidth=2, label='Reconstruction')
ax1.tick_params(axis='y', labelcolor=color_recon)
ax1.grid(True, linestyle='--', alpha=0.6)

# Création d'un deuxième axe pour la KL Loss qui a une échelle différente
ax2 = ax1.twinx()
color_kl = 'tab:orange'
ax2.set_ylabel('KL Divergence Loss', color=color_kl, fontsize=12)
ax2.plot(betas, kl_losses, marker='s', color=color_kl, linewidth=2, linestyle='--', label='KL Divergence')
ax2.tick_params(axis='y', labelcolor=color_kl)

plt.title("Équilibre entre Reconstruction et Régularisation", fontsize=14, pad=20)
fig.tight_layout()
plt.show()

# --- PLOT 2 : SCORE DE SILHOUETTE (Bar Chart) ---
plt.figure(figsize=(10, 5))
bars = plt.bar([str(b) for b in betas], silhouette_scores, color='teal', alpha=0.8)

# Ajouter les valeurs au-dessus des barres
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.005, round(yval, 3), ha='center', va='bottom', fontweight='bold')

plt.xlabel('Valeur de Beta ($\\beta$)', fontsize=12)
plt.ylabel('Silhouette Score', fontsize=12)
plt.title("Qualité de la séparation des groupes dans l'espace latent", fontsize=14, pad=20)
plt.ylim(0, max(silhouette_scores) * 1.2) # Laisser de l'espace pour les étiquettes
plt.grid(axis='y', linestyle=':', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Analyse du compromis (Image 3 : Reconstruction vs KL)
#
# C'est ici que l'on voit le fameux "trade-off" :
#
# * **Entre $\beta=0.1$ et $\beta=0.5$** : La **Reconstruction Loss** (bleue) descend légèrement. C'est le "point idéal" pour la fidélité audio.
# * **À partir de $\beta=1$** : L'erreur de reconstruction commence à grimper de façon linéaire pour exploser à **5.6** quand $\beta=5$.
# * **La KL Loss** (orange) s'écrase totalement à $\beta=5$. Le modèle ne retient plus assez d'informations pour reconstruire la chanson, il se contente de "ranger" les points n'importe où pour plaire à la contrainte mathématique.
#
# ##### 2. Le verdict du Silhouette Score (Image 4)
#
# -> Les scores sont **négatifs** (entre -0.14 et -0.19).
#
# * **Traduction :** Les morceaux de différents genres se chevauchent énormément dans l'espace latent. Les clusters ne sont pas encore bien séparés.
# * Cependant, on remarque que le score est "moins pire" pour **$\beta=0.1$**, **$0.5$** et **$1.0$**. À **$5.0$**, la qualité chute encore plus (-0.197).
#
#
#
# ##### 🏁 Recommandation :
#
# C'est la valeur qui offre le meilleur compromis actuel :
#
# 1. C'est là que la **Reconstruction Loss** est la plus basse (environ **3.0**).
# 2. C'est là que le **Silhouette Score** est parmi les plus "hauts".
# 3. Cela laisse assez de liberté au modèle pour apprendre les détails audio sans trop le brider.
#
#
#
# ##### 🛠 Pourquoi les scores sont négatifs et comment corriger ?
#
# Les premières courbes (Images 1 et 2) montrent que l'entraînement est encore très **instable** (les dents de scie). Le modèle n'a pas eu le temps de se "poser" dans une solution propre.
#
# **Pistes pour la suite :**
#
# * **Baisser le Learning Rate :** Les oscillations sont trop fortes. On peut passer à `learning_rate=0.0001` ou même `0.00005`.
# * **Augmenter les époques :** Avec un petit learning rate, il faudra peut-être 150 ou 200 époques pour que les courbes deviennent lisses.
# * **Vérifier la dimension latente :** Si ils existent beaucoup de genres différents, compresser tout ça en seulement **4 dimensions** est peut-être trop brutal. On essaie de passer à **8 ou 16** pour voir si le score de silhouette repasse dans le positif.
#
# ---

# %% [markdown]
# ### VAE Final:

# %%
NEW_latent_dim = 8 # Taille de l'espace latent (le "résumé" de la musique)


input_dim = df_scaled.shape[1]
# --- ENCODEUR ---
encoder_inputs = keras.Input(shape=(input_dim,))
x = layers.Dense(16, activation="relu")(encoder_inputs)
x = layers.Dense(8, activation="relu")(x)

z_mean = layers.Dense(NEW_latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(NEW_latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])

encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")

# --- DÉCODEUR ---
latent_inputs = keras.Input(shape=(NEW_latent_dim,))
x = layers.Dense(8, activation="relu")(latent_inputs)
x = layers.Dense(16, activation="relu")(x)
decoder_outputs = layers.Dense(input_dim, activation="sigmoid")(x)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")

# %%
NEW_beta = 0.3

vae_final = beta_VAE(encoder, decoder, beta=NEW_beta)
vae_final.compile(optimizer=keras.optimizers.Adam(learning_rate=5e-5))

history_vae_final = vae_final.fit(
    x_train, 
    epochs=200, 
    batch_size=128, 
    verbose=1 
)

# Visualisation de la perte
plt.figure(figsize=(14, 5))

# Sous-graphique 1 : Perte Totale
plt.subplot(1, 2, 1)
plt.plot(history_vae_final.history['loss'], label='Total Loss', color='purple', lw=2)
plt.title("Évolution de la Perte Totale (VAE)")
plt.xlabel("Époques")
plt.ylabel("Loss")
plt.legend()
plt.grid(alpha=0.3)

# Sous-graphique 2 : Décomposition Reconstruction vs KL
plt.subplot(1, 2, 2)
plt.plot(history_vae_final.history['reconstruction_loss'], label='Reconstruction Loss', color='blue')
plt.plot(history_vae_final.history['kl_loss'], label='KL Divergence Loss', color='orange')
plt.title("Reconstruction vs Régularisation KL")
plt.xlabel("Époques")
plt.ylabel("Loss")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/200
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 1s 547us/
200
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - kl_loss: 2.9739 - loss: 3.6824 - reconstruction_loss: 2.7903
# Epoch 199/200
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - kl_loss: 2.9757 - loss: 3.6831 - reconstruction_loss: 2.7904
# Epoch 200/200
# 164/164 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - kl_loss: 2.9823 - loss: 3.6733 - reconstruction_loss: 2.7786

# %% [markdown]
# ### Visualisation de l'espace latent (dim=8)

# %%
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Extraction des vecteurs latents (z_mean)
# On utilise z_mean car c'est la représentation "stable" apprise par le VAE
z_mean, _, _ = vae_final.encoder.predict(df_scaled)

# 2. Réduction de dimension avec t-SNE
# perplexity: balance entre l'aspect local et global (entre 30 et 50 généralement)
tsne = TSNE(n_components=2, perplexity=30, max_iter=1000, random_state=42, verbose=1)
z_tsne = tsne.fit_transform(z_mean)

# 3. Préparation du DataFrame pour le plot
# On récupère les genres pour mettre de la couleur
df_plot = pd.DataFrame(z_tsne, columns=['Dim 1', 'Dim 2'])
df_plot['Genre'] = df['playlist_subgenre'].values

# Optionnel : On ne garde que les 10 genres les plus fréquents pour plus de clarté
top_genres = df['playlist_subgenre'].value_counts().nlargest(10).index
df_plot_filtered = df_plot[df_plot['Genre'].isin(top_genres)]
# Out:
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 276us/step
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 26230 samples in 0.008s...
# [t-SNE] Computed neighbors for 26230 samples in 0.392s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 26230
# [t-SNE] Computed conditional probabilities for sample 2000 / 26230
# [t-SNE] Computed conditional probabilities for sample 3000 / 26230
# [t-SNE] Computed conditional probabilities for sample 4000 / 26230
# [t-SNE] Computed conditional probabilities for sample 5000 / 26230
# [t-SNE] Computed conditional probabilities for sample 6000 / 26230
# [t-SNE] Computed conditional probabilities for sample 7000 / 26230
# [t-SNE] Computed conditional probabilities for sample 8000 / 26230
# [t-SNE] Computed conditional probabilities for sample 9000 / 26230
# [t-SNE] Computed conditional probabilities for sample 10000 / 26230
# [t-SNE] Computed conditional probabilities for sample 11000 / 26230
# [t-SNE] Computed conditional probabilities for sample 12000 / 26230
# [t-SNE] Computed conditional probabilities for sample 13000 / 26230
# [t-SNE] Computed conditional probabilities for sample 14000 / 26230
# [t-SNE] Computed conditional probabilities for sample 15000 / 26230
# [t-SNE] Computed conditional probabilities for sample 16000 / 26230
# [t-SNE] Computed conditional probabilities for sample 17000 / 26230
# [t-SNE] Computed conditional probabilities for sample 18000 / 26230
# [t-SNE] Computed conditional probabilities for sample 19000 / 26230
# [t-SNE] Computed conditional probabilities for sample 20000 / 26230
# [t-SNE] Computed conditional probabilities for sample 21000 / 26230
# [t-SNE] Computed conditional probabilities for sample 22000 / 26230
# [t-SNE] Computed conditional probabilities for sample 23000 / 26230
# [t-SNE] Computed conditional probabilities for sample 24000 / 26230
# [t-SNE] Computed conditional probabilities for sample 25000 / 26230
# [t-SNE] Computed conditional probabilities for sample 26000 / 26230
# [t-SNE] Computed conditional probabilities for sample 26230 / 26230
# [t-SNE] Mean sigma: 0.063850
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.309982
# [t-SNE] KL divergence after 1000 iterations: 1.129526

# %% [markdown]
# ### Affichage --- Subgenre

# %%
# 4. Affichage
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df_plot_filtered, 
    x='Dim 1', 
    y='Dim 2', 
    hue='Genre', 
    palette='viridis', 
    alpha=0.6,
    s=20
)

plt.title("Visualisation t-SNE de l'espace latent (VAE)", fontsize=15)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Sous-genres')
plt.grid(alpha=0.2)
plt.show()

# %% [markdown]
# ### Affichage --- Popularité

# %%
# 1. On s'assure d'avoir les données de popularité
df_plot['Popularity'] = df['track_popularity'].values

plt.figure(figsize=(12, 8))
# On utilise une palette de type 'magma' ou 'viridis' pour bien voir le gradient
scatter = plt.scatter(
    df_plot['Dim 1'], 
    df_plot['Dim 2'], 
    c=df_plot['Popularity'], 
    cmap='magma', 
    alpha=0.5, 
    s=15
)

plt.colorbar(scatter, label='Popularité (0-100)')
plt.title("Distribution de la Popularité dans l'Espace Latent VAE", fontsize=15)
plt.xlabel("Dim 1")
plt.ylabel("Dim 2")
plt.grid(alpha=0.2)
plt.show()

# %% [markdown]
# ### Affichage --- Genre Principal

# %%
df_plot['Main_Genre'] = df['playlist_genre'].values

plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df_plot, 
    x='Dim 1', 
    y='Dim 2', 
    hue='Main_Genre', 
    palette='Set1', # Palette distincte pour les catégories
    alpha=0.4, 
    s=20
)

plt.title("Séparation par Genres Principaux (t-SNE)", fontsize=15)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Genres')
plt.show()

# %% [markdown]
# ### 6 bis. Test

# %%
# 1. Prédire les vecteurs latents (on prend uniquement z_mean)
z_mean_tracks, _, _ = vae_final.encoder.predict(df_scaled)

def recommend_vae(song_name, df, latent_vectors, n=5):
    if song_name not in df['track_name'].values:
        return "Chanson introuvable."
    
    # Trouver l'index de la chanson cible
    idx = df[df['track_name'] == song_name].index[0]
    target_vec = latent_vectors[idx].reshape(1, -1)
    
    # Calculer la similarité cosinus dans l'espace VAE
    from sklearn.metrics.pairwise import cosine_similarity
    sim = cosine_similarity(target_vec, latent_vectors)[0]
    
    # Trier et récupérer les indices (exclure le premier qui est la chanson elle-même)
    best_indices = sim.argsort()[::-1][1:n+1]
    
    return df.iloc[best_indices][['track_name', 'track_artist', 'track_album_release_date', 'playlist_genre','playlist_subgenre']]

# TEST
print("🔥 Recommandations via VAE for the track : " + str(df['track_name'].iloc[34]))
display(recommend_vae(df['track_name'].iloc[34], df, z_mean_tracks))
# Out:
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step
# 🔥 Recommandations via VAE for the track : Quite Miss Home - Steve Void Remix
#                              track_name        track_artist  \
# 32554   Dreamer - Matisse & Sadko Remix  Axwell /\ Ingrosso
# 17094                           Happier                Koni
# 20350                       Poco A Poco          Luis Fonsi
# 12770                        He Got You       Ronnie Milsap
# 17305  Wave Goodbye (feat. Jeffrey Jey)        Robin Schulz
#
#       track_album_release_date playlist_genre          playlist_subgenre
# 32554               2018-02-02            edm  progressive electro house
# 17094               2018-09-21          latin                   tropical
# 20350               2019-02-01          latin              latin hip hop
# 12770               1982-05-01           rock               classic rock
# 17305               2015-09-25          latin                   tropical
